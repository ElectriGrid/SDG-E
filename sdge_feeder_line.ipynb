# %% [markdown]
# # Exploring SDG&E Data
#
# This data is downloaded in a different format than the other electricity grid data. Instead of line this the electric grid is in polygons. This notebook explores how to handle the polygon data.
#
# ### Explore the difference between the generation and load capacity
# The definitions below are sourced from the SDG&E metadata. This was downloaded directly from the SDG&E website under the ICA User Guide it can be accessed [here](https://interconnectionmapsdge.extweb.sempra.com/#).
#
# - **Generation Capacity MW (ICA)** – the maximum amount of capacity available to connect to the distribution system
# - **Load Capacity MW (LCA)** -  maximum amount of power available to be drawn from the distribution system

# %%
# load necessary libraries
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## SDG&E Load Capacity

# %%
# load SDGE load capacity data
sdge_load_capacity = gpd.read_file("../../../../capstone/electrigrid/data/utilities/sandiego_grid/ICA_MAP_PROD_LoadCapacityGrids.geojson")

# %%
# check the crs 
sdge_load_capacity.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
sdge_load_capacity.head()
# Out:
#    OBJECTID  VOLTAGE  LINE_SEGMENT_NUMBER  ICAWOF_UNIGENERATION  \
# 0  31786423       12               156597                   0.0
# 1  31786424       12               156597                   0.0
# 2  31786425       12               156597                   0.0
# 3  31786426       12               156597                   0.0
# 4  31786427       12               156597                   0.0
#
#    ICAWOF_UNILOAD  ICAWOF_PVGENERATION OHUG CIRCUIT_NAME LABELTEXT  \
# 0             1.1                  0.0   UG          597      None
# 1             1.1                  0.0   UG          597      None
# 2             1.1                  0.0   UG          597      None
# 3             1.1                  0.0   UG          597      None
# 4             1.1                  0.0   UG          597      None
#
#    ICAWNOF_UNIGENERATION  ICAWNOF_UNILOAD  ICAWNOF_PVGENERATION LABELTEXT_LCA  \
# 0                    0.0              1.1                   0.4     1.00-1.50
# 1                    0.0              1.1                   0.4     1.00-1.50
# 2                    0.0              1.1                   0.4     1.00-1.50
# 3                    0.0              1.1                   0.4     1.00-1.50
# 4                    0.0              1.1                   0.4     1.00-1.50
#
#   RESTRICTED       SUBID ICAWOF_UNIGENERATION_LC ICAWOF_UNILOAD_LC  \
# 0          N  SAN MARCOS      ICA_Operation_Flex      Load_Voltage
# 1          N  SAN MARCOS      ICA_Operation_Flex      Load_Voltage
# 2          N  SAN MARCOS      ICA_Operation_Flex      Load_Voltage
# 3          N  SAN MARCOS      ICA_Operation_Flex      Load_Voltage
# 4          N  SAN MARCOS      ICA_Operation_Flex      Load_Voltage
#
#   ICAWNOF_UNIGENERATION_LC                                           geometry
# 0              ICA_Voltage  POLYGON ((-117.18286 33.10932, -117.18286 33.1...
# 1              ICA_Voltage  POLYGON ((-117.18286 33.10898, -117.18286 33.1...
# 2              ICA_Voltage  POLYGON ((-117.18286 33.10864, -117.18286 33.1...
# 3              ICA_Voltage  POLYGON ((-117.18286 33.10829, -117.18286 33.1...
# 4              ICA_Voltage  POLYGON ((-117.18286 33.10795, -117.18286 33.1...

# %%
# dataframe size
sdge_load_capacity.shape
# Out:
# (477123, 19)

# %%
# check the load capacity geom type
sdge_load_capacity.geom_type
# Out:
# 0         Polygon
# 1         Polygon
# 2         Polygon
# 3         Polygon
# 4         Polygon
#            ...
# 477118    Polygon
# 477119    Polygon
# 477120    Polygon
# 477121    Polygon
# 477122    Polygon
# Length: 477123, dtype: object

# %%
# initial plot of load capacity
fig, ax = plt.subplots()

sdge_load_capacity.plot(ax=ax)

plt.show()

# %% [markdown]
# ## SDG&E Generation Capacity

# %%
# load SDGE generation capacity data
sdge_generation_capacity = gpd.read_file("../../../../capstone/electrigrid/data/utilities/sandiego_grid/ICA_MAP_PROD_GenerationCapacityGrids.geojson")

# %%
# check the size of the generation capacity
sdge_generation_capacity.shape
# Out:
# (477123, 19)

# %%
# check the type of geometry
sdge_generation_capacity.geom_type
# Out:
# 0         Polygon
# 1         Polygon
# 2         Polygon
# 3         Polygon
# 4         Polygon
#            ...
# 477118    Polygon
# 477119    Polygon
# 477120    Polygon
# 477121    Polygon
# 477122    Polygon
# Length: 477123, dtype: object

# %%
sdge_generation_capacity.head()
# Out:
#    OBJECTID  VOLTAGE  LINE_SEGMENT_NUMBER  ICAWOF_UNIGENERATION  \
# 0  32500971       12               189790                   0.0
# 1  32500972       12               189790                   0.0
# 2  32500973       12               189790                   0.0
# 3  32500974       12               189790                   0.0
# 4  32500975       12               846583                   0.0
#
#    ICAWOF_UNILOAD  ICAWOF_PVGENERATION OHUG CIRCUIT_NAME LABELTEXT  \
# 0             2.1                  0.2   OH          204      None
# 1             2.1                  0.2   OH          204      None
# 2             2.1                  0.2   OH          204      None
# 3             2.1                  0.2   OH          204      None
# 4             3.0                  0.2   OH          204      None
#
#    ICAWNOF_UNIGENERATION  ICAWNOF_UNILOAD  ICAWNOF_PVGENERATION LABELTEXT_ICA  \
# 0                    1.1              2.1                   1.3             0
# 1                    1.1              2.1                   1.3             0
# 2                    1.1              2.1                   1.3             0
# 3                    1.1              2.1                   1.3             0
# 4                    0.1              3.0                   0.7             0
#
#   RESTRICTED      SUBID ICAWOF_UNIGENERATION_LC ICAWOF_UNILOAD_LC  \
# 0          N  SAN MATEO      ICA_Operation_Flex      Load_Voltage
# 1          N  SAN MATEO      ICA_Operation_Flex      Load_Voltage
# 2          N  SAN MATEO      ICA_Operation_Flex      Load_Voltage
# 3          N  SAN MATEO      ICA_Operation_Flex      Load_Voltage
# 4          N  SAN MATEO      ICA_Operation_Flex      Load_Voltage
#
#   ICAWNOF_UNIGENERATION_LC                                           geometry
# 0              ICA_Voltage  POLYGON ((-117.51529 33.39328, -117.51529 33.3...
# 1              ICA_Voltage  POLYGON ((-117.51529 33.39294, -117.51529 33.3...
# 2              ICA_Voltage  POLYGON ((-117.51611 33.39362, -117.51611 33.3...
# 3              ICA_Voltage  POLYGON ((-117.51611 33.39328, -117.51611 33.3...
# 4              ICA_Voltage  POLYGON ((-117.55531 33.37352, -117.55532 33.3...

# %%
# check CRS
sdge_generation_capacity.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
type(sdge_generation_capacity)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# initial plot of generation capacity
fig, ax = plt.subplots()

sdge_generation_capacity.plot(ax=ax)
plt.show()

# %% [markdown]
# ## Difference between the load and generation capacities

# %%
# make sure the crs match 
assert sdge_load_capacity.crs == sdge_generation_capacity.crs

# %% [markdown]
# Lets see if we can find the difference between the two capacity maps.

# %%
# calculate the difference between the generation and load capacity
load_gen_diff = sdge_generation_capacity["ICAWOF_UNILOAD"]- sdge_load_capacity["ICAWOF_UNILOAD"]

# make the series a data frame
load_gen_diff = load_gen_diff.to_frame()

# add a geometry layer
load_gen_diff["geometry"] = sdge_load_capacity["geometry"]

# make sure the type is a dataframe
type(load_gen_diff)

# %% [markdown]
# Even though geometry was added the dataframe needs to be converted to a GeoPandas Dataframe for mapping.

# %%
load_gen_diff = gpd.GeoDataFrame(load_gen_diff, 
                                 geometry = 'geometry')
load_gen_diff.head()
# Out:
#    ICAWOF_UNILOAD                                           geometry
# 0             1.0  POLYGON ((-117.18286 33.10932, -117.18286 33.1...
# 1             1.0  POLYGON ((-117.18286 33.10898, -117.18286 33.1...
# 2             1.0  POLYGON ((-117.18286 33.10864, -117.18286 33.1...
# 3             1.0  POLYGON ((-117.18286 33.10829, -117.18286 33.1...
# 4             1.9  POLYGON ((-117.18286 33.10795, -117.18286 33.1...

# %%
# check the range of values for the difference between the generation and load capacity
print(load_gen_diff['ICAWOF_UNILOAD'].min())
print(load_gen_diff['ICAWOF_UNILOAD'].max())
# Out:
# -10.0
# 10.0

# %%
# look at all the unique values
list(load_gen_diff['ICAWOF_UNILOAD'].unique())
# Out:
# [1.0,
#  1.9,
#  1.8,
#  1.1000000000000003,
#  1.0000000000000002,
#  0.9000000000000001,
#  1.7,
#  1.4000000000000001,
#  1.3,
#  2.8999999999999995,
#  2.8,
#  0.8,
#  -0.3999999999999999,
#  -0.09999999999999964,
#  -0.9000000000000001,
#  -0.10000000000000009,
#  0.3999999999999999,
#  1.2999999999999998,
#  -1.0000000000000002,
#  -1.4000000000000001,
#  -1.1999999999999997,
#  -0.19999999999999973,
#  -2.2,
#  0.5,
#  0.6000000000000001,
#  0.7,
#  0.10000000000000009,
#  1.5000000000000002,
#  0.5000000000000001,
#  0.0,
#  -0.09999999999999987,
#  3.0,
#  3.1,
#  0.40000000000000013,
#  0.7000000000000002,
#  -0.19999999999999996,
#  2.2,
#  0.20000000000000018,
#  -3.4,
#  -3.5,
#  -4.3,
#  -4.4,
#  -0.30000000000000027,
#  0.8000000000000003,
#  1.2,
#  2.0,
#  0.09999999999999998,
#  0.20000000000000007,
#  -0.29999999999999993,
#  0.8999999999999999,
#  -0.30000000000000004,
#  1.1,
#  -0.6000000000000001,
#  -0.5,
#  -1.2000000000000002,
#  -1.1,
#  -0.8,
#  -0.5999999999999996,
#  1.7999999999999998,
#  0.30000000000000027,
#  1.6,
#  1.4,
#  0.30000000000000004,
#  2.0999999999999996,
#  1.1999999999999997,
#  1.3000000000000003,
#  1.6999999999999997,
#  2.3,
#  0.7999999999999998,
#  -1.0999999999999996,
#  1.5,
#  -1.6,
#  -1.5,
#  -1.6999999999999997,
#  -1.0,
#  -1.5999999999999996,
#  -1.4,
#  -0.8999999999999999,
#  -0.4999999999999998,
#  0.5999999999999999,
#  -0.7999999999999998,
#  -2.4,
#  0.2999999999999998,
#  -1.2,
#  -0.9,
#  -3.0,
#  -0.7,
#  2.7,
#  2.1000000000000005,
#  1.0999999999999999,
#  -0.20000000000000018,
#  -0.2999999999999998,
#  -1.2999999999999998,
#  1.2000000000000002,
#  1.8000000000000003,
#  1.4000000000000004,
#  0.6000000000000003,
#  -1.9,
#  1.9999999999999998,
#  0.6999999999999997,
#  2.5,
#  0.40000000000000036,
#  0.5999999999999996,
#  1.7000000000000002,
#  1.7999999999999994,
#  -2.3,
#  -3.6,
#  -5.2,
#  2.3000000000000003,
#  1.5999999999999999,
#  -7.199999999999999,
#  2.9,
#  -3.0000000000000004,
#  -3.1000000000000005,
#  2.8000000000000003,
#  -7.0,
#  -3.5000000000000004,
#  -6.300000000000001,
#  -0.7000000000000002,
#  -1.8,
#  1.4999999999999998,
#  1.9000000000000001,
#  0.9999999999999998,
#  2.4,
#  4.0,
#  -2.799999999999999,
#  -2.1999999999999997,
#  -0.6999999999999993,
#  1.7000000000000006,
#  1.0000000000000004,
#  -2.4000000000000004,
#  -4.5,
#  -6.4,
#  -7.2,
#  1.0999999999999996,
#  2.1,
#  -3.3000000000000003,
#  -3.8000000000000003,
#  -6.9,
#  -7.3,
#  3.3999999999999995,
#  -3.7,
#  -4.0,
#  -6.7,
#  -0.6999999999999997,
#  2.0000000000000004,
#  -5.0,
#  2.9999999999999996,
#  -4.6,
#  1.2000000000000006,
#  5.3,
#  3.0000000000000004,
#  -4.6000000000000005,
#  -7.5,
#  3.7,
#  4.199999999999999,
#  4.5,
#  5.699999999999999,
#  5.1,
#  5.800000000000001,
#  2.4000000000000004,
#  -7.699999999999999,
#  6.1000000000000005,
#  4.2,
#  4.1,
#  6.0,
#  -3.2,
#  -6.699999999999999,
#  -7.4,
#  -3.9,
#  -4.8,
#  -1.5999999999999999,
#  -8.0,
#  -5.1,
#  -1.4999999999999998,
#  3.2,
#  3.3000000000000003,
#  1.8999999999999995,
#  0.19999999999999973,
#  -0.40000000000000013,
#  -3.6000000000000005,
#  -2.0000000000000004,
#  -2.2000000000000006,
#  -4.500000000000001,
#  -0.7000000000000001,
#  0.3,
#  0.6,
#  -9.3,
#  -5.800000000000001,
#  -8.4,
#  -5.300000000000001,
#  -2.8,
#  -8.200000000000001,
#  -2.1,
#  -1.7000000000000002,
#  -0.4,
#  -2.9,
#  0.2,
#  -2.8000000000000003,
#  -1.3,
#  -2.6,
#  -1.8000000000000003,
#  -9.5,
#  -4.7,
#  -2.7,
#  -2.0,
#  -1.3000000000000003,
#  -6.1000000000000005,
#  -6.2,
#  -4.2,
#  -5.3,
#  -5.3999999999999995,
#  3.4000000000000004,
#  -3.1,
#  -5.9,
#  -2.0999999999999996,
#  2.1999999999999997,
#  -1.5000000000000002,
#  -3.4000000000000004,
#  -1.7999999999999998,
#  -0.5000000000000001,
#  -2.5,
#  7.500000000000001,
#  -9.4,
#  -9.9,
#  7.0,
#  4.7,
#  4.6,
#  -1.9000000000000001,
#  0.5000000000000002,
#  4.6000000000000005,
#  3.6999999999999997,
#  -5.7,
#  -9.200000000000001,
#  -3.3,
#  -9.8,
#  -9.1,
#  -9.700000000000001,
#  0.1,
#  -2.6999999999999997,
#  -3.1999999999999997,
#  -0.09999999999999998,
#  0.7000000000000001,
#  -1.7,
#  7.7,
#  5.8,
#  2.6,
#  3.5,
#  -4.9,
#  -2.3000000000000003,
#  5.300000000000001,
#  3.4,
#  4.800000000000001,
#  4.300000000000001,
#  3.0999999999999996,
#  2.5000000000000004,
#  -6.0,
#  0.8000000000000002,
#  -1.0999999999999999,
#  8.100000000000001,
#  -0.3,
#  -0.2,
#  6.7,
#  -0.4000000000000001,
#  0.7999999999999999,
#  0.9,
#  0.09999999999999987,
#  0.19999999999999996,
#  0.4999999999999998,
#  -0.6,
#  0.4,
#  -9.2,
#  1.3999999999999995,
#  -1.1000000000000003,
#  -0.5000000000000002,
#  2.1999999999999993,
#  -0.8000000000000003,
#  -2.5999999999999996,
#  -3.3999999999999995,
#  -5.1000000000000005,
#  -1.4000000000000004,
#  -2.9999999999999996,
#  -1.4999999999999996,
#  3.6,
#  2.6000000000000005,
#  3.9,
#  6.2,
#  6.3,
#  6.4,
#  5.9,
#  6.5,
#  6.3999999999999995,
#  5.2,
#  -0.19999999999999998,
#  9.7,
#  9.8,
#  7.8,
#  5.000000000000001,
#  6.300000000000001,
#  -0.39999999999999997,
#  -0.6000000000000003,
#  -1.9000000000000004,
#  -0.9000000000000004,
#  0.9999999999999999,
#  0.39999999999999997,
#  -3.4999999999999996,
#  -3.5999999999999996,
#  -3.9000000000000004,
#  -0.5999999999999999,
#  2.7000000000000006,
#  -2.9000000000000004,
#  2.2000000000000006,
#  3.5000000000000004,
#  2.9000000000000004,
#  3.3000000000000007,
#  3.8000000000000003,
#  -2.6999999999999993,
#  -3.0999999999999996,
#  -1.9999999999999996,
#  -1.3999999999999995,
#  -1.7999999999999994,
#  2.500000000000001,
#  0.09999999999999964,
#  -0.49999999999999956,
#  -2.4999999999999996,
#  -2.1999999999999993,
#  -3.8000000000000007,
#  -1.6000000000000005,
#  -0.40000000000000036,
#  -0.7999999999999994,
#  -0.9999999999999996,
#  1.9999999999999996,
#  -1.2999999999999994,
#  -0.4999999999999999,
#  8.3,
#  -1.0000000000000004,
#  -2.8000000000000007,
#  -4.1,
#  -4.1000000000000005,
#  -1.8999999999999995,
#  4.1000000000000005,
#  4.000000000000001,
#  -0.5000000000000009,
#  1.4999999999999996,
#  -0.3000000000000007,
#  2.5999999999999996,
#  -3.8,
#  -1.5000000000000004,
#  -2.1000000000000005,
#  0.5000000000000009,
#  1.5000000000000004,
#  -1.6000000000000003,
#  -2.5000000000000004,
#  1.5999999999999996,
#  -0.9999999999999998,
#  -2.8999999999999995,
#  2.8000000000000007,
#  1.6000000000000005,
#  -0.9999999999999999,
#  2.4999999999999996,
#  0.49999999999999956,
#  0.39999999999999947,
#  3.7000000000000006,
#  0.9999999999999996,
#  2.6999999999999993,
#  0.6000000000000005,
#  -0.10000000000000053,
#  -3.3000000000000007,
#  -4.000000000000001,
#  -0.8000000000000002,
#  -2.3999999999999995,
#  0.3000000000000007,
#  2.3999999999999995,
#  0.7999999999999994,
#  -3.6999999999999997,
#  1.2999999999999994,
#  3.4999999999999996,
#  -1.0000000000000009,
#  -0.20000000000000007,
#  3.9000000000000004,
#  -0.7999999999999999,
#  3.3,
#  6.8999999999999995,
#  4.4,
#  4.3,
#  4.8,
#  5.6,
#  1.6000000000000003,
#  3.6000000000000005,
#  3.1000000000000005,
#  5.6000000000000005,
#  0.9000000000000004,
#  -7.8,
#  -6.6,
#  -4.300000000000001,
#  -0.8000000000000007,
#  0.2999999999999994,
#  -4.200000000000001,
#  3.1999999999999997,
#  4.3999999999999995,
#  -8.7,
#  -8.8,
#  -6.8,
#  -1.9999999999999998,
#  -7.1000000000000005,
#  -5.000000000000001,
#  0.8000000000000007,
#  5.1000000000000005,
#  -5.4,
#  -4.800000000000001,
#  2.6999999999999997,
#  -5.6000000000000005,
#  0.10000000000000053,
#  -5.6,
#  -5.5,
#  7.300000000000001,
#  -0.1,
#  -4.699999999999999,
#  -5.8,
#  -6.199999999999999,
#  -6.3,
#  -7.6,
#  -5.699999999999999,
#  -4.199999999999999,
#  -6.1,
#  -8.100000000000001,
#  -5.500000000000001,
#  -9.6,
#  -8.9,
#  -8.6,
#  0.29999999999999993,
#  -5.8999999999999995,
#  3.5999999999999996,
#  5.0,
#  -4.3999999999999995,
#  0.19999999999999998,
#  7.5,
#  5.5,
#  -4.8999999999999995,
#  -6.5,
#  6.199999999999999,
#  3.2000000000000006,
#  5.500000000000001,
#  4.699999999999999,
#  -7.7,
#  3.8,
#  -1.8000000000000007,
#  5.199999999999999,
#  -1.1999999999999993,
#  1.1000000000000005,
#  -5.199999999999999,
#  0.8999999999999995,
#  1.9000000000000004,
#  -10.0,
#  8.5,
#  5.3999999999999995,
#  3.9999999999999996,
#  6.1,
#  3.8000000000000007,
#  4.9,
#  7.4,
#  8.6,
#  -3.7000000000000006,
#  -2.7000000000000006,
#  -7.9,
#  -2.6000000000000005,
#  -5.200000000000001,
#  7.3,
#  -3.2000000000000006,
#  6.6,
#  8.0,
#  1.1999999999999993,
#  5.8999999999999995,
#  4.700000000000001,
#  6.800000000000001,
#  7.700000000000001,
#  -0.10000000000000003,
#  7.699999999999999,
#  9.5,
#  7.1,
#  7.6,
#  9.9,
#  9.2,
#  6.8,
#  7.9,
#  -3.9999999999999996,
#  -7.1,
#  0.10000000000000003,
#  3.8999999999999995,
#  -0.5000000000000004,
#  -1.3000000000000007,
#  6.9,
#  5.7,
#  10.0,
#  8.2,
#  -0.6000000000000005,
#  0.1999999999999993,
#  -1.1000000000000005,
#  -7.500000000000001,
#  -8.3,
#  -3.8999999999999995,
#  5.4,
#  -0.39999999999999947,
#  8.4,
#  -6.499999999999999,
#  9.4,
#  -5.499999999999999,
#  1.8000000000000007,
#  -8.2,
#  5.999999999999999,
#  5.899999999999999,
#  6.699999999999999,
#  -6.000000000000001,
#  -7.8999999999999995,
#  7.2,
#  7.1000000000000005,
#  8.9,
#  -6.299999999999999,
#  -0.8999999999999995,
#  -8.5,
#  9.0,
#  -4.700000000000001,
#  9.700000000000001,
#  8.8,
#  -8.700000000000001,
#  8.700000000000001,
#  -7.3999999999999995,
#  7.199999999999999,
#  7.6000000000000005,
#  6.799999999999999,
#  5.200000000000001,
#  6.000000000000001,
#  7.100000000000001,
#  -7.6000000000000005,
#  9.3,
#  9.200000000000001,
#  5.700000000000001,
#  8.600000000000001,
#  0.4999999999999999,
#  8.7,
#  -8.1,
#  -7.300000000000001,
#  -7.800000000000001,
#  -6.6000000000000005,
#  8.200000000000001,
#  8.1,
#  4.8999999999999995,
#  -7.000000000000001,
#  9.6,
#  6.6000000000000005,
#  5.299999999999999,
#  -6.3999999999999995,
#  0.6999999999999993,
#  -6.800000000000001,
#  1.3000000000000007,
#  0.4000000000000001,
#  -2.500000000000001,
#  4.500000000000001,
#  -1.2000000000000006,
#  1.6999999999999993,
#  7.3999999999999995,
#  -6.700000000000001,
#  -5.700000000000001,
#  7.200000000000001,
#  -7.700000000000001,
#  -1.7000000000000006,
#  -7.200000000000001,
#  -6.200000000000001,
#  -9.0,
#  -6.8999999999999995,
#  -9.7,
#  1.0000000000000009,
#  -4.499999999999999,
#  -6.100000000000001,
#  -8.299999999999999,
#  -9.299999999999999,
#  -9.000000000000002,
#  -8.799999999999999,
#  -6.999999999999999,
#  -0.2999999999999994,
#  9.1,
#  7.800000000000001,
#  2.000000000000001,
#  4.200000000000001,
#  9.600000000000001,
#  -6.500000000000001,
#  9.299999999999999,
#  6.299999999999999,
#  6.100000000000001,
#  7.600000000000001,
#  6.700000000000001,
#  6.600000000000001,
#  1.1000000000000014,
#  -1.5000000000000009,
#  -5.100000000000001,
#  8.299999999999999,
#  0.20000000000000107,
#  5.799999999999999,
#  2.3000000000000007,
#  -0.1999999999999993,
#  -2.4000000000000012,
#  -8.600000000000001,
#  5.499999999999999,
#  -6.799999999999999,
#  -5.799999999999999,
#  6.500000000000001,
#  -0.7000000000000006,
#  7.8999999999999995,
#  8.500000000000002,
#  9.100000000000001,
#  9.000000000000002,
#  -7.400000000000001,
#  -3.000000000000001,
#  -3.1999999999999993,
#  6.999999999999999,
#  8.000000000000002,
#  -5.299999999999999,
#  -7.900000000000001,
#  -9.100000000000001,
#  -2.3000000000000007,
#  7.000000000000001,
#  7.499999999999999,
#  -7.799999999999999,
#  6.200000000000001,
#  0.9999999999999991,
#  1.9999999999999991,
#  -6.900000000000001,
#  -5.999999999999999,
#  -6.600000000000001,
#  -7.600000000000001,
#  -7.299999999999999,
#  -8.000000000000002,
#  -7.100000000000001,
#  -2.499999999999999,
#  7.900000000000001,
#  5.600000000000001,
#  1.700000000000001,
#  0.29999999999999893,
#  2.499999999999999,
#  -9.500000000000002,
#  1.5000000000000009,
#  3.000000000000001,
#  -7.999999999999999,
#  -4.799999999999999,
#  4.799999999999999,
#  3.299999999999999,
#  3.999999999999999,
#  4.399999999999999,
#  4.899999999999999,
#  4.299999999999999,
#  -2.000000000000001,
#  -3.500000000000001,
#  2.999999999999999,
#  4.900000000000001,
#  3.499999999999999,
#  -1.6999999999999993,
#  -0.20000000000000107,
#  -0.29999999999999893,
#  4.400000000000001,
#  -3.9000000000000012,
#  2.0999999999999988]

# %%
fig, ax = plt.subplots()

load_gen_diff.plot(column = 'ICAWOF_UNILOAD',
                   ax=ax)
plt.show()
# Out:
# /tmp/ipykernel_1734209/3180348378.py:3: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   load_gen_diff.plot(column = 'ICAWOF_UNILOAD',

# %% [markdown]
# There are some difference between generation and load. Most notably there are some negative values meaning that according to the data some locations are already drawing more data than is available to be connected to the distribution system.
